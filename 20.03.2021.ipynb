# %%
import pandas as pd
from pandas import read_csv
from Bio import Entrez
import os
import urllib
import sys
import urllib.request
import urllib
import time

import shutil




seq = pd.read_csv('C://Users/amand/Bacteriophages/sequences.csv') 
#seq

#new dataframe with individual columns
new_seq = seq[['Assembly', 'Species', 'Molecule_type', 'Family', 'Host', 'GenBank_Title']].copy()
#new_seq


#sorting values by Host and Family
new_seq.sort_values(by=['Host', 'Family'])

#searching Family Siphoviridae which Host is Lactococcus lactis
siphoviridae = new_seq.loc [(new_seq['Family'] == 'Siphoviridae') & (new_seq['Host'] == 'Lactococcus lactis')] 
siphoviridae

asb = siphoviridae["Assembly"].tolist()


def get_this(phages_list):


    urllib.request.urlretrieve("https://ftp.ncbi.nlm.nih.gov/genomes/refseq/assembly_summary_refseq.txt", "assembly_summary_refseq.txt")
    assembly_sum = pd.read_csv('assembly_summary_refseq.txt', sep='\t', skiprows=1)
    assembly_sum.columns = ["assembly_accession", "bioproject", "biosample", "wgs_master", "refseq_category", "taxid", "species_taxid", "organism_name", "infraspecific_name", "isolate", "version_status", "assembly_level", "release_type", "genome_rep", "seq_rel_date", "asm_name", "submitter", "gbrs_paired_asm", "paired_asm_comp", "ftp_path", "excluded_from_refseq", "relation_to_type_material"]

    for id in phages_list:
        my_df=assembly_sum[(assembly_sum['assembly_accession'] == id)] #& (assembly_sum['version_status'] == 'latest')]
        my_df = my_df[['ftp_path','assembly_accession','asm_name']]
        #print(my_df)
        #Process the newly created file and download genomes from NCBI website
        data = my_df['ftp_path'].tolist() 
        #print(data)
        for elem in data:
       #     try:    
            file = str(id)
            file_suffix='_genomic.fna.gz'
            ftpfile = urllib.request.urlretrieve(elem+file_suffix)
        #    except:
                  #  print("-I- Skipping",file," - doesn't exist.")

    return

get_this(asb)
# Out:
# ---------------------------------------------------------------------------
# error_perm                                Traceback (most recent call last)
# D:\anaconndaa\lib\urllib\request.py in retrfile(self, file, type)
#    2450                     try:
# -> 2451                         self.ftp.cwd(file)
#    2452                     except ftplib.error_perm as reason:
#
# D:\anaconndaa\lib\ftplib.py in cwd(self, dirname)
#     613         cmd = 'CWD ' + dirname
# --> 614         return self.voidcmd(cmd)
#     615
#
# D:\anaconndaa\lib\ftplib.py in voidcmd(self, cmd)
#     279         self.putcmd(cmd)
# --> 280         return self.voidresp()
#     281
#
# D:\anaconndaa\lib\ftplib.py in voidresp(self)
#     252         """Expect a response beginning with '2'."""
# --> 253         resp = self.getresp()
#     254         if resp[:1] != '2':
#
# D:\anaconndaa\lib\ftplib.py in getresp(self)
#     247         if c == '5':
# --> 248             raise error_perm(resp)
#     249         raise error_proto(resp)
#
# error_perm: 550 GCF_009685705.1_ASM968570v1_genomic.fna.gz: No such file or directory
#
# The above exception was the direct cause of the following exception:
#
# URLError                                  Traceback (most recent call last)
# D:\anaconndaa\lib\urllib\request.py in ftp_open(self, req)
#    1573                     type = value.upper()
# -> 1574             fp, retrlen = fw.retrfile(file, type)
#    1575             headers = ""
#
# D:\anaconndaa\lib\urllib\request.py in retrfile(self, file, type)
#    2452                     except ftplib.error_perm as reason:
# -> 2453                         raise URLError('ftp error: %r' % reason) from reason
#    2454                 finally:
#
# URLError: <urlopen error ftp error: error_perm('550 GCF_009685705.1_ASM968570v1_genomic.fna.gz: No such file or directory')>
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-4-90f3b966043f> in <module>
#      56     return
#      57
# ---> 58 get_this(asb)
#
# <ipython-input-4-90f3b966043f> in get_this(phages_list)
#      50             file = str(id)
#      51             file_suffix='_genomic.fna.gz'
# ---> 52             ftpfile = urllib.request.urlretrieve(elem+file_suffix)
#      53         #    except:
#      54                   #  print("-I- Skipping",file," - doesn't exist.")
#
# D:\anaconndaa\lib\urllib\request.py in urlretrieve(url, filename, reporthook, data)
#     245     url_type, path = _splittype(url)
#     246
# --> 247     with contextlib.closing(urlopen(url, data)) as fp:
#     248         headers = fp.info()
#     249
#
# D:\anaconndaa\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# D:\anaconndaa\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523
#     524         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# D:\anaconndaa\lib\urllib\request.py in _open(self, req, data)
#     540
#     541         protocol = req.type
# --> 542         result = self._call_chain(self.handle_open, protocol, protocol +
#     543                                   '_open', req)
#     544         if result:
#
# D:\anaconndaa\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# D:\anaconndaa\lib\urllib\request.py in ftp_open(self, req)
#    1583         except ftplib.all_errors as exp:
#    1584             exc = URLError('ftp error: %r' % exp)
# -> 1585             raise exc.with_traceback(sys.exc_info()[2])
#    1586
#    1587     def connect_ftp(self, user, passwd, host, port, dirs, timeout):
#
# D:\anaconndaa\lib\urllib\request.py in ftp_open(self, req)
#    1572                    value in ('a', 'A', 'i', 'I', 'd', 'D'):
#    1573                     type = value.upper()
# -> 1574             fp, retrlen = fw.retrfile(file, type)
#    1575             headers = ""
#    1576             mtype = mimetypes.guess_type(req.full_url)[0]
#
# D:\anaconndaa\lib\urllib\request.py in retrfile(self, file, type)
#    2451                         self.ftp.cwd(file)
#    2452                     except ftplib.error_perm as reason:
# -> 2453                         raise URLError('ftp error: %r' % reason) from reason
#    2454                 finally:
#    2455                     self.ftp.cwd(pwd)
#
# URLError: <urlopen error ftp error: URLError("ftp error: error_perm('550 GCF_009685705.1_ASM968570v1_genomic.fna.gz: No such file or directory')")>
